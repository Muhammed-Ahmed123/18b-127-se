# %%
import networkx as nx
import matplotlib.pyplot as plt
g=nx.read_edgelist('untitled.txt',create_using=nx.Graph(),nodetype=str)
print (nx.info(g))
nx.draw(g)
plt.show()
# Out:
# Name:
# Type: Graph
# Number of nodes: 53
# Number of edges: 48
# Average degree:   1.8113
